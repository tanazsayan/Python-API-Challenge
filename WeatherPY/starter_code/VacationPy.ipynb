# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# !pip install geoviews cartopy

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head(30)
# Out:
#     City_ID                          City      Lat       Lng  Max Temp  \
# 0         0                   pangnirtung  66.1451  -65.7125    241.15
# 1         1                    kaitangata -46.2817  169.8464    283.40
# 2         2                       ushuaia -54.8000  -68.3000    285.96
# 3         3                    morant bay  17.8815  -76.4093    302.99
# 4         4                     kavaratti  10.5669   72.6420    299.71
# 5         5                        barrow  71.2906 -156.7887    246.16
# 6         6  presidencia roque saenz pena -26.7852  -60.4388    296.72
# 7         7                        castro -24.7911  -50.0119    293.11
# 8         8                          daru  -9.0763  143.2092    298.44
# 9         9                   port alfred -33.5906   26.8910    292.69
# 10       10                        mbaiki   3.8678   17.9892    299.71
# 11       11                        bethel  41.3712  -73.4140    288.08
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng", 
    "Lat",
    geo = True,
    size = "Humidity",
    scale = 1.0,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
clean_df = city_data_df.dropna(how='any')
clean_df.count()
# Out:
# City_ID       573
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
clean_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  pangnirtung  66.1451  -65.7125    241.15        62          20
# 1        1   kaitangata -46.2817  169.8464    283.40        94          78
# 2        2      ushuaia -54.8000  -68.3000    285.96        71          40
# 3        3   morant bay  17.8815  -76.4093    302.99        66           4
# 4        4    kavaratti  10.5669   72.6420    299.71        69          22
#
#    Wind Speed Country        Date
# 0        0.00      CA  1676655152
# 1        1.65      NZ  1676655153
# 2        6.69      AR  1676655153
# 3        5.42      JM  1676655154
# 4        2.40      IN  1676655154

# %%
clean_df["New Temp"] = (9/5) * (clean_df["Max Temp"] - 273.15) + 32
clean_df.head()
# Out:
# C:\Users\tanaa\AppData\Local\Temp\ipykernel_14756\3496247576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df["New Temp"] = (9/5) * (clean_df["Max Temp"] - 273.15) + 32
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  pangnirtung  66.1451  -65.7125    241.15        62          20
# 1        1   kaitangata -46.2817  169.8464    283.40        94          78
# 2        2      ushuaia -54.8000  -68.3000    285.96        71          40
# 3        3   morant bay  17.8815  -76.4093    302.99        66           4
# 4        4    kavaratti  10.5669   72.6420    299.71        69          22
#
#    Wind Speed Country        Date  New Temp
# 0        0.00      CA  1676655152   -25.600
# ...

# %%
# Narrow down cities that fit criteria and drop any results with null values
vacation_weather_df = clean_df.loc[(clean_df["New Temp"] < 80) & (clean_df["New Temp"] > 70) & 
                                  (clean_df["Wind Speed"] < 4.5) & (clean_df["Cloudiness"] == 0)]

# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
vacation_weather_df.head()
# Out:
#      City_ID      City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 30        30     ojhar  20.1000  73.9333    295.41        18           0
# 101      101       sur  22.5667  59.5289    296.46        52           0
# 137      137  shirgaon  19.7000  72.7000    298.70        41           0
# 242      242   jodhpur  26.2867  73.0300    296.79        16           0
# 354      354   salalah  17.0151  54.0924    298.20        69           0
#
#      Wind Speed Country        Date  New Temp
# 30         2.04      IN  1676655164    72.068
# 101        0.64      OM  1676655194    73.958
# 137        3.04      IN  1676655218    77.990
# 242        1.61      IN  1676655270    74.552
# 354        1.54      OM  1676655327    77.090

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = vacation_weather_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#          City Country      Lat       Lng  Humidity Hotel Name
# 30      ojhar      IN  20.1000   73.9333        18
# 101       sur      OM  22.5667   59.5289        52
# 137  shirgaon      IN  19.7000   72.7000        41
# 242   jodhpur      IN  26.2867   73.0300        16
# 354   salalah      OM  17.0151   54.0924        69
# 453    ixtapa      MX  20.7000 -105.2000        64
# 484     nizwa      OM  22.9333   57.5333        18

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
#Set parameters to search for a hotel
radius = 10000
params = {
    "apiKey":geoapify_key,
    "format":"json",
    "categories" : "accommodation.hotel",
    "limits" : 1
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, "Lat"]
    longitude = hotel_df.loc[index, "Lng"]
# Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["city"] = hotel_df.loc[index, "City"] 
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Get response and Convert the API response to JSON format
    name_address = requests.get(base_url,params=params).json()
    
    #print(json.dumps(name_address,indent=4, sort_keys=True))
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
# Display sample data
hotel_df
# Out:
# Starting hotel search
# ojhar - nearest hotel: No hotel found
# sur - nearest hotel: Sur Hotel
# shirgaon - nearest hotel: KD Residency
# jodhpur - nearest hotel: khass baag
# salalah - nearest hotel: Muscat International Hotel
# ixtapa - nearest hotel: Ma. Cristina
# nizwa - nearest hotel: Nizwa Heritage Inn
#          City Country      Lat       Lng  Humidity                  Hotel Name
# 30      ojhar      IN  20.1000   73.9333        18              No hotel found
# 101       sur      OM  22.5667   59.5289        52                   Sur Hotel
# 137  shirgaon      IN  19.7000   72.7000        41                KD Residency
# 242   jodhpur      IN  26.2867   73.0300        16                  khass baag
# 354   salalah      OM  17.0151   54.0924        69  Muscat International Hotel
# 453    ixtapa      MX  20.7000 -105.2000        64                Ma. Cristina
# 484     nizwa      OM  22.9333   57.5333        18          Nizwa Heritage Inn

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# %%capture --no-display

# Configure the map plot
map_plt_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo =True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 1.0,
    alpha = 0.8,
    color = "City",
    hover_cols = "Hotel Name"
)



# Display the map
map_plt_2

# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name)
